# %% [markdown]
# ## Setup

# %%
from ultralytics import YOLO

# %% [markdown]
# ## ! ALWAYS CHECK MODEL YOU TRAIN !
#
# Może będzie trzeba zrobić to:
#
# W pliku: "C:\Users\Prezes\AppData\Local\Programs\Python\Python310\Lib\site-packages\ultralytics\engine\trainer.py"
#
# Zmiana linii nr.237 z:
#
# self.amp = torch.tensor(self.args.amp).to(self.device)  # True or False
#
# na
#
# self.amp = False

# %%
from ultralytics import YOLO
model = YOLO('C:\Projekty\PracaInz\Models\yolov8n.pt')
YOLO.amp = False
model.train(data=r'C:\Projekty\PracaInz\Data\Datasets\CFPW_dataset_manual\data.yaml', 
            epochs=200, 
            save_period=1, 
            amp=False, 
            half=False,
            optimizer='SGD',
            flipud=0.1,
            mosaic=1,
            scale=0.3,
            lr0=0.002,
            degrees=10
            )
# Out:
# New https://pypi.org/project/ultralytics/8.0.222 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.167  Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1650 Ti, 4096MiB)
# ...

# %%
from ultralytics import YOLO
# Load a model
model = YOLO(r"C:\Projekty\PracaInz\Programs\runs\detect\train3\weights\last.pt")  # load a partially trained model

# Resume training
results = model.train(resume=True)
# Out:
# New https://pypi.org/project/ultralytics/8.0.171 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.167  Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1650 Ti, 4096MiB)
# ...
